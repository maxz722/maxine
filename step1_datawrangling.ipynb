# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as py

# %%
df = pd.read_csv('listings.csv', low_memory=False)

# %%
print(df)
# Out:
#             id                            listing_url       scrape_id  \
# 0          958       https://www.airbnb.com/rooms/958  20191204162709
# 1         3850      https://www.airbnb.com/rooms/3850  20191204162709
# 2         5858      https://www.airbnb.com/rooms/5858  20191204162709
# 3         7918      https://www.airbnb.com/rooms/7918  20191204162709
# 4         8142      https://www.airbnb.com/rooms/8142  20191204162709
# ...        ...                                    ...             ...
# 8528  40544136  https://www.airbnb.com/rooms/40544136  20191204162709
# 8529  40546145  https://www.airbnb.com/rooms/40546145  20191204162709
# 8530  40547706  https://www.airbnb.com/rooms/40547706  20191204162709
# 8531  40560328  https://www.airbnb.com/rooms/40560328  20191204162709
# 8532  40569280  https://www.airbnb.com/rooms/40569280  20191204162709
#
#      last_scraped                                               name  \
# ...

# %%
df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20191204162709   2019-12-04
# 1  3850  https://www.airbnb.com/rooms/3850  20191204162709   2019-12-04
# 2  5858  https://www.airbnb.com/rooms/5858  20191204162709   2019-12-05
# 3  7918  https://www.airbnb.com/rooms/7918  20191204162709   2019-12-04
# 4  8142  https://www.airbnb.com/rooms/8142  20191204162709   2019-12-04
#
#                                                 name  \
# 0                Bright, Modern Garden Unit - 1BR/1B
# 1                              Charming room for two
# 2                                 Creative Sanctuary
# 3         A Friendly Room - UCSF/USF - San Francisco
# 4  Friendly Room Apt. Style -UCSF/USF - San Franc...
#
#                                              summary  \
# 0  New update: the house next door is under const...
# 1  Your own private room plus access to a shared ...
# ...

# %%
df.shape
# Out:
# (8533, 106)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8533 entries, 0 to 8532
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(23), int64(21), object(62)
# memory usage: 6.9+ MB

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8533 entries, 0 to 8532
# Data columns (total 106 columns):
# id                                              int64
# listing_url                                     object
# scrape_id                                       int64
# last_scraped                                    object
# name                                            object
# summary                                         object
# space                                           object
# description                                     object
# experiences_offered                             object
# neighborhood_overview                           object
# notes                                           object
# transit                                         object
# access                                          object
# interaction                                     object
# house_rules                                     object
# ...

# %%
#checking if any columns have null
pd.isnull(df).any()
# Out:
# id                                              False
# listing_url                                     False
# scrape_id                                       False
# last_scraped                                    False
# name                                            False
#                                                 ...
# calculated_host_listings_count                  False
# calculated_host_listings_count_entire_homes     False
# calculated_host_listings_count_private_rooms    False
# calculated_host_listings_count_shared_rooms     False
# reviews_per_month                                True
# Length: 106, dtype: bool

# %%
df.dropna(how='all')
df.dropna(thresh=2)
# Out:
#             id                            listing_url       scrape_id  \
# 0          958       https://www.airbnb.com/rooms/958  20191204162709
# 1         3850      https://www.airbnb.com/rooms/3850  20191204162709
# 2         5858      https://www.airbnb.com/rooms/5858  20191204162709
# 3         7918      https://www.airbnb.com/rooms/7918  20191204162709
# 4         8142      https://www.airbnb.com/rooms/8142  20191204162709
# ...        ...                                    ...             ...
# 8528  40544136  https://www.airbnb.com/rooms/40544136  20191204162709
# 8529  40546145  https://www.airbnb.com/rooms/40546145  20191204162709
# 8530  40547706  https://www.airbnb.com/rooms/40547706  20191204162709
# 8531  40560328  https://www.airbnb.com/rooms/40560328  20191204162709
# 8532  40569280  https://www.airbnb.com/rooms/40569280  20191204162709
#
#      last_scraped                                               name  \
# ...

# %%
df['price'] = df['price'].str.lstrip('$')
df['weekly_price']= df['weekly_price'].str.lstrip('$')
df['monthly_price']= df['monthly_price'].str.lstrip('$')
df['security_deposit'] = df['security_deposit'].str.lstrip('$')
df['cleaning_fee']= df['cleaning_fee'].str.lstrip('$')
df['extra_people']= df['extra_people'].str.lstrip('$')

# %%
# changing object to numeric values
numeric_cols = ['price','weekly_price','monthly_price','monthly_price',
                'security_deposit','cleaning_fee','extra_people']

# %%
## keep getting errors for trying to iterate over multiple columns
def omit_dollar_sign(row):
    return df[numeric_cols].lstrip('$')
#f[numeric_cols].apply(omit_dollar_sign)

#df[numeric_cols].apply()

# %%
df[numeric_cols].describe()
# Out:
#          price weekly_price monthly_price monthly_price security_deposit  \
# count     8533         1053          1026          1026             6774
# unique     526          321           310           310               96
# top     150.00     1,000.00      3,500.00      3,500.00             0.00
# freq       274           49            42            42             2257
#
#        cleaning_fee extra_people
# count          7574         8533
# unique          194           81
# top          100.00         0.00
# freq            754         4715

# %%
df[numeric_cols] #.fillna(0, inplace = True) #this function makes it return null
# for NaN, want to make calculations & add another column that flags that it's a manual adjustment
# Out:
#        price weekly_price monthly_price monthly_price security_deposit  \
# 0     170.00     1,120.00      4,200.00      4,200.00           100.00
# 1      99.00          NaN           NaN           NaN             0.00
# 2     235.00     1,600.00      5,500.00      5,500.00              NaN
# 3      65.00       485.00      1,685.00      1,685.00           200.00
# 4      65.00       490.00      1,685.00      1,685.00           200.00
# ...      ...          ...           ...           ...              ...
# 8528   95.00          NaN           NaN           NaN             0.00
# 8529   55.00          NaN           NaN           NaN              NaN
# 8530  100.00          NaN           NaN           NaN           500.00
# 8531  295.00          NaN           NaN           NaN              NaN
# 8532   60.00          NaN           NaN           NaN              NaN
#
#      cleaning_fee extra_people
# 0          100.00        25.00
# 1           10.00        20.00
# ...

# %%
df[numeric_cols].apply(pd.to_numeric, errors = 'coerce') #making it into a numeric
# Out:
#       price  weekly_price  monthly_price  monthly_price  security_deposit  \
# 0     170.0           NaN            NaN            NaN             100.0
# 1      99.0           NaN            NaN            NaN               0.0
# 2     235.0           NaN            NaN            NaN               NaN
# 3      65.0         485.0            NaN            NaN             200.0
# 4      65.0         490.0            NaN            NaN             200.0
# ...     ...           ...            ...            ...               ...
# 8528   95.0           NaN            NaN            NaN               0.0
# 8529   55.0           NaN            NaN            NaN               NaN
# 8530  100.0           NaN            NaN            NaN             500.0
# 8531  295.0           NaN            NaN            NaN               NaN
# 8532   60.0           NaN            NaN            NaN               NaN
#
#       cleaning_fee  extra_people
# 0            100.0          25.0
# ...

# %%
df[numeric_cols].describe()
# Out:
#          price weekly_price monthly_price monthly_price security_deposit  \
# count     8533         1053          1026          1026             6774
# unique     526          321           310           310               96
# top     150.00     1,000.00      3,500.00      3,500.00             0.00
# freq       274           49            42            42             2257
#
#        cleaning_fee extra_people
# count          7574         8533
# unique          194           81
# top          100.00         0.00
# freq            754         4715

# %%
# want to omit null columns if it is an object
